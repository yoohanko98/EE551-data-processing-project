# %% [markdown]
# ## EE 551 Data Processing Project
# ### Yoohan Ko, Cole Yarbrough
# "I pledge my honor I have abided by the Stevens Honor System" -YHK, CY

# %%
import pandas as pd
import numpy as np
import csv 

rawData = pd.read_csv("energy.csv", encoding='latin-1')
# rawData = csv.reader(open('energy.csv'))

# %%
rawData
# Out:
#                       T24 Production, trade and supply of energy Unnamed: 2  \
# 0     Region/Country/Area                                    NaN       Year
# 1                       1          Total, all countries or areas       1990
# 2                       1          Total, all countries or areas       1995
# 3                       1          Total, all countries or areas       2000
# 4                       1          Total, all countries or areas       2005
# ...                   ...                                    ...        ...
# 8289                  716                               Zimbabwe       2005
# 8290                  716                               Zimbabwe       2010
# 8291                  716                               Zimbabwe       2014
# 8292                  716                               Zimbabwe       2015
# 8293                  716                               Zimbabwe       2016
#
# ...
